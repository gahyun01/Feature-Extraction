# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        'name':['박지성', '이영표', '차두리'],
        'position':['MF', 'DF', '차미네이터'],
        'age':[25, 27, 30]
    }
)

# %%
df
# Out:
#   name position  age
# 0  박지성       MF   25
# 1  이영표       DF   27
# 2  차두리    차미네이터   30

# %%
df = pd.read_csv('exam.csv')

# %%
df.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
df.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
music = pd.read_csv('music.csv')

# %%
music.describe()
# Out:
#        personnel
# count  13.000000
# mean    5.230769
# std     2.712743
# min     1.000000
# 25%     4.000000
# 50%     5.000000
# 75%     7.000000
# max    11.000000

# %%
music.dtypes
# Out:
# title           object
# singer          object
# personnel        int64
# sortation       object
# release_date    object
# agency          object
# genre           object
# type            object
# dtype: object

# %%
music.sort_values(['personnel', 'release_date'])
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
# ...

# %%
music.sort_values(['personnel', 'release_date'],
                  ascending=[True, False])   # release_date는 내림차순임
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# ...

# %%
music.agency.value_counts().sort_values(ascending=True)
# Out:
# 카카오엔터테인먼트                1
# 바나나컬쳐                    1
# 울림엔터테인먼트                 1
# 쏘스뮤직                     1
# YMC엔터테인먼트, 스톤뮤직엔터테인먼트    1
# JYP엔터테인먼트                1
# SM엔터테인먼트                 2
# 빅히트뮤직                    2
# YG엔터테인먼트                 3
# Name: agency, dtype: int64

# %%
music.agency.unique()
# Out:
# array(['카카오엔터테인먼트', 'YG엔터테인먼트', 'SM엔터테인먼트', '바나나컬쳐', '울림엔터테인먼트', '빅히트뮤직',
#        '쏘스뮤직', 'YMC엔터테인먼트, 스톤뮤직엔터테인먼트', 'JYP엔터테인먼트'], dtype=object)

# %%
music.agency.nunique()
# Out:
# 9

# %%
weather = pd.read_excel('weather.xlsx')

# %%
weather.평균기온
# Out:
# 0     22.1
# 1     21.5
# 2     24.5
# 3     25.6
# 4     22.7
# 5     19.7
# 6     20.6
# 7     21.2
# 8     20.9
# 9     20.9
# 10    24.6
# 11    24.6
# 12    23.6
# 13    21.5
# 14    17.5
# 15    20.3
# 16    22.5
# 17    23.3
# 18    23.4
# 19    25.2
# 20    26.5
# 21    25.9
# 22    24.3
# 23    22.6
# 24    26.0
# 25    26.5
# 26    26.8
# 27    26.9
# 28    25.1
# 29    22.3
# Name: 평균기온, dtype: float64

# %%
cols = weather[['평균기온', '최저기온', '최고기온']]
cols.head()
# Out:
#             평균기온  최저기온  최고기온
# 날짜
# 2022-06-01  22.1  16.2  28.6
# 2022-06-02  21.5  17.1  26.9
# 2022-06-03  24.5  18.7  32.6
# 2022-06-04  25.6  20.3  29.7
# 2022-06-05  22.7  20.2  27.0

# %%
weather.columns[2:]
# Out:
# Index(['최저기온', '최고기온'], dtype='object')

# %%
weather.iloc[:, 1:].head()
# Out:
#    평균기온  최저기온  최고기온
# 0  22.1  16.2  28.6
# 1  21.5  17.1  26.9
# 2  24.5  18.7  32.6
# 3  25.6  20.3  29.7
# 4  22.7  20.2  27.0

# %%
weather.loc[:5, cols]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-f873003749d9> in <cell line: 1>()
# ----> 1 weather.loc[:5, cols]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
cond1 = weather['최고기온']>30
cond2 = weather['최저기온']<20
weather[cond1 & cond2]   # True인 행 ( 교집합 )
# Out:
#            날짜  평균기온  최저기온  최고기온
# 2  2022-06-03  24.5  18.7  32.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5

# %%
weather[cond1 | cond2]   # True인 행 ( 합집합 )
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5

# %%
weather = weather.set_index("날짜")

# %%
weather
# Out:
#             평균기온  최저기온  최고기온
# 날짜
# 2022-06-01